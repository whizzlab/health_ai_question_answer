# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import re

# %% [markdown]
# # load data

# %%
all_abstracts = pd.read_csv('data/included_abstracts.csv', index_col = 0)

all_abstracts['article_date'] = pd.to_datetime(all_abstracts['article_date'])
decade_df = all_abstracts[(all_abstracts['article_date'] > '2012-01-01') & (all_abstracts['article_date'] <'2022-01-01')]
len(decade_df)
# Out:
# 28703

# %%
methods_df = pd.read_csv('output/methods_scored.csv', index_col = 0)
print(len(methods_df))
methods_df.info()
# Out:
# 27252
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27252 entries, 0 to 27251
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pmid               27252 non-null  int64
#  1   title              27251 non-null  object
#  2   methods            27252 non-null  object
#  3   sample_answer      27252 non-null  object
#  4   sample_score       24580 non-null  float64
#  5   sample_answer_2    27252 non-null  object
#  6   sample_score_2     24580 non-null  float64
#  7   database_answer    27252 non-null  object
#  8   database_score     24580 non-null  float64
#  9   database_answer_2  27252 non-null  object
#  10  database_score_2   24580 non-null  float64
#  11  location_answer    27252 non-null  object
#  12  location_score     24580 non-null  float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 2.9+ MB

# %%
abstracts_df = pd.read_csv('output/abstracts_scored.csv', index_col = 0)
print(len(abstracts_df))
abstracts_df.info()
# Out:
# 28703
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28703 entries, 0 to 28702
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pmid                 28703 non-null  int64
#  1   title                28702 non-null  object
#  2   abstract             28703 non-null  object
#  3   disease_answer       28703 non-null  object
#  4   disease_score        28703 non-null  float64
#  5   sample_answer        28703 non-null  object
#  6   sample_score         28703 non-null  float64
#  7   modality_answer      28703 non-null  object
#  8   modality_score       28703 non-null  float64
#  9   database_answer      28703 non-null  object
#  10  database_score       28703 non-null  float64
#  11  organisation_answer  28703 non-null  object
#  12  organisation_score   28703 non-null  float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 3.1+ MB

# %% [markdown]
# # combined columns

# %%
abstract_databases = abstracts_df[['pmid', 'abstract', 'database_answer', 'database_score', 'organisation_answer', 'organisation_score']].copy()
abstract_databases.rename(columns={"database_answer": "abstract_db", "database_score": "abstract_db_score",
                                  "organisation_answer": "abstract_org", "organisation_score": "abstract_org_score"}, inplace=True)

method_databases = methods_df[['pmid', 'methods', 'database_answer', 'database_score', 'database_answer_2', 'database_score_2', 
                               'location_answer', 'location_score']].copy()
method_databases.rename(columns={"database_answer": "method_db", "database_score": "method_db_score",
                                 "database_answer_2": "method_db_2", "database_score_2": "method_db_score_2",
                                  "location_answer": "method_org", "location_score": "method_org_score"}, inplace=True)

# %%
all_database = abstract_databases.merge(method_databases, on = 'pmid', how = 'left')
all_database = all_database[['pmid', 'abstract', #'methods', 
                             'abstract_db', 'abstract_db_score',
                             'abstract_org', 'abstract_org_score', 
                             'method_db' ,'method_db_score', 'method_db_2' ,'method_db_score_2',
                            'method_org', 'method_org_score']].astype('object')

# %%
all_database.sample(50)
# Out:
#            pmid                                           abstract  \
# 8989   32880677  Acute kidney injury (AKI) is a deleterious com...
# 2828   34334334  Parkinson's disease is heterogeneous in sympto...
# 9550   30638592  Premature ventricular contraction is associate...
# 19443  31571320  Machine learning has increasingly been applied...
# 20254  34008178  To develop a radiomic model predicting nonresp...
# 8622   34927854  Colorectal cancer (CRC) is the third most comm...
# 28343  32747203  Machine learning models used to predict postop...
# 4828   34707347  To evaluate a deep learning-based method to au...
# 28017  34307860  Medical imaging refers to visualization techni...
# 8358   33590485  To develop and validate a deep learning algori...
# 2790   33850243  Chronic Kidney Disease (CKD) represents a slow...
# 5900   34879850  Gestational diabetes mellitus (GDM) is one of ...
# 18868  23070357  The objective of this study was to compare the...
# 14684  22836876  The purpose of this study was to validate the ...
# 16455  33007891  Blood pressure monitoring is one avenue to mon...
# 22065  30453231  Ultrasound imaging of the thyroid gland is con...
# 16204  33266481  In this paper, we introduce a simple method ba...
# 26092  33172897  Gastric cancer remains the leading cause of ca...
# 18677  28650804  Myoelectric signals can be used to predict the...
# 25009  34297300  For cancer prediction, the prognostic stage is...
# 4669   33611873  Many deep learning-based predictive models eva...
# 17654  34621541  We seek the development and evaluation of a fa...
# 5526   23415158  Quasi-supervised learning is a statistical lea...
# 3819   32686721  Most screening tests for T2DM in use today wer...
# 25081  32154669  More than 750Â 000 women in Italy are survivin...
# 27153  34969636  Low-dose computed tomography (LDCT) are perfor...
# 17907  29993526  The aim of this research was to develop a swal...
# 14628  32256007  Diabetic Mellitus is the leading disease in th...
# 11643  30333744  <b>Background</b>: Among the neurodegenerative...
# 23948  24307992  We report an automated diagnostic test that us...
# 8233   28358032  Classification is one of the most important ta...
# 15359  34389924  Our objective is to identify the predictive fa...
# 11215  34993145  To develop a clinical-radiomics model based on...
# 19860  25574185  Activity recognition is needed in different re...
# 25877  34931154  Detecting COVID-19 early may help in devising ...
# 16978  33391011  A mixed literature implicates atypical connect...
# 15757  34713109  Alzheimer's disease (AD) is an irreversible br...
# 26417  34013107  Acute kidney injury (AKI) is common among hosp...
# 26399  34033251  To identity phenotypes of self-reported sympto...
# 25262  32174313  Determining which patients are ready for disch...
# 3748   33128961  Pressure mapping technology has been adapted t...
# 16582  34066001  Several scoring systems have been devised to o...
# 12808  34489684  Dual pathology of Alzheimer's disease (AD) and...
# 17140  32384716  Human motion detection is getting considerable...
# 20821  31392088  Cecal intubation time is an important componen...
# 28691  32165206  Histologic subtypes of malignant pleural mesot...
# 8598   32222795  We develop and validate a radiomics model base...
# 25707  34843559  Highly accurate detection of intracranial hemo...
# 15930  33680925  Craniopharyngiomas (CPs) are benign tumors, co...
# 27348  30328624  Precise segmentation of bladder walls and tumo...
#
#                                              abstract_db abstract_db_score  \
# 8989                                       two hospitals          0.594497
# 2828   Parkinson's Progression Markers Initiative (PP...          0.440794
# 9550                                      Holter devices          0.046926
# 19443  resting-state functional magnetic resonance im...          0.099084
# 20254                                     LaTIM UMR 1101          0.179352
# 8622                                    discovery cohort          0.011372
# 28343                                  Tertiary hospital          0.231173
# 4828       anterior segment optical coherence tomography           0.01934
# 28017                                           ImageNet           0.16953
# 8358         tissue microarrays of colorectal carcinomas          0.377676
# 2790                                             biobank          0.195167
# 5900                                       eastern China          0.514235
# 18868                            ankle and wrist sensors          0.061237
# 14684  European Organization for Research and Treatme...          0.515352
# 16455  Physionet's multiparameter intelligent monitor...          0.536439
# 22065  Computer aided diagnosis (CAD) systems can off...          0.006031
# 16204                            finger-nose-finger test          0.002636
# 26092                           2,434 whole-slide images          0.100671
# 18677  untrained upper-limb positions for amputee and...          0.003968
# 25009               India's reputed medical institutions           0.30384
# 4669                                              ECG II          0.526818
# 17654  20 brain, 50 breast, and 50 lung cancer patien...          0.245338
# 5526                colorectal radical surgery materials          0.216426
# 3819                       electronically collected data          0.208081
# 25081                        Nottingham Prognostic Index          0.413575
# 27153                                       routine NCCT          0.224267
# 17907  140 healthy subjects (54.5 32.5 years old) and...          0.013068
# 14628                                    public hospital          0.218036
# 11643                                       metabolomics          0.047534
# 23948                                       988 patients          0.063375
# 8233         structural magnetic resonance imaging (MRI)          0.124136
# 15359                    Max group of hospitals in India          0.690413
# 11215                   Peking University First Hospital          0.195807
# 19860                              reconnaissance system          0.042336
# 25877                                           COVID-19          0.067066
# 16978                 Multimodal Treatment Study of ADHD          0.574644
# 15757        Alzheimer's Disease Neuroimaging Initiative          0.251771
# 26417    Medical Information Mart for Intensive Care III           0.29819
# 26399            Symptom Checklist 90-Revised (SCL-90-R)          0.010521
# 25262      three ICUs in a Brazilian university hospital          0.051678
# 3748                                           test data           0.04759
# 16582                                        Fudan score           0.11454
# 12808                                                MRI          0.004961
# 17140                                              SDRs)          0.344759
# 20821                                    medical records          0.125828
# 28691                                  surgical biopsies          0.019378
# 8598   multiparametric magnetic resonance imaging (MR...          0.050422
# 25707                                              AIDOC          0.252763
# 15930                                          radiomics          0.040382
# 27348  3.0T T2-weighted MRI scans from 60 pathologica...          0.050256
#
#                                             abstract_org abstract_org_score  \
# 8989                                       two hospitals           0.294958
# 2828          Parkinson's Progression Markers Initiative            0.30993
# 9550                            Artificial Immune System           0.014237
# 19443                       different sites and scanners           0.023352
# 20254  multicenter pretherapeutic contrast-enhanced c...           0.043352
# 8622                                              plasma           0.002002
# 28343                                  Tertiary hospital           0.229364
# 4828                   cornea specialist ophthalmologist            0.01614
# 28017                                           ImageNet           0.143138
# 8358         tissue microarrays of colorectal carcinomas           0.083935
# 2790                                             biobank           0.195787
# 5900                          primary health care centre           0.603538
# 18868                            ankle and wrist sensors           0.055283
# 14684  European Organization for Research and Treatme...           0.539062
# 16455  Physionet's multiparameter intelligent monitor...           0.497825
# 22065             Computer aided diagnosis (CAD) systems           0.013983
# 16204                   patients and healthy individuals           0.002122
# 26092  2,434 whole-slide images, we developed an algo...           0.010306
# 18677  prosthesis control. However, untrained effects...           0.001428
# 25009               India's reputed medical institutions           0.339668
# 4669                                              ECG II           0.082269
# 17654  20 brain, 50 breast, and 50 lung cancer patien...            0.01888
# 5526                          colorectal radical surgery           0.080389
# 3819                            electronically collected           0.061415
# 25081                        Nottingham Prognostic Index           0.102459
# 27153                                       routine NCCT           0.049333
# 17907                                     simple sensors           0.005395
# 14628                                    public hospital           0.134318
# 11643                                                RFA           0.020705
# 23948        633 normal and 355 who required colonoscopy           0.005191
# 8233   structural magnetic resonance imaging (MRI) or...           0.007151
# 15359                    Max group of hospitals in India           0.620075
# 11215                   Peking University First Hospital           0.381616
# 19860                              reconnaissance system            0.02581
# 25877                     X-Ray, Ultrasound, and CT scan           0.013572
# 16978                 Multimodal Treatment Study of ADHD           0.571551
# 15757        Alzheimer's Disease Neuroimaging Initiative           0.042254
# 26417    Medical Information Mart for Intensive Care III           0.115993
# 26399                       temporal lobe epilepsy (TLE)           0.001403
# 25262                      Brazilian university hospital           0.405734
# 3748                              two monitoring systems           0.007236
# 16582                               tertiary care center           0.166273
# 12808                                   vascular disease           0.001007
# 17140                     software-defined radios (SDRs)           0.113616
# 20821                                    medical records           0.065709
# 28691                                  pathologic slides           0.007699
# 8598   multiparametric magnetic resonance imaging (MR...           0.010487
# 25707                             teleradiology services           0.179391
# 15930                                          radiomics           0.010935
# 27348       60 pathologically confirmed patients with BC           0.004516
#
#                                                method_db method_db_score  \
# 8989               korean society of nephrology registry        0.082059
# 2828   parkinson's progression markers initiative (ppmi)        0.444845
# 9550   mit-bih arrhythmia database (ardb) and mit-bih...        0.155041
# 19443                                            rsfmri)         0.00575
# 20254                                             french        0.005813
# 8622                                                 NaN             NaN
# 28343  institutional electronic medical records, soci...        0.465651
# 4828                         bascom palmer eye institute        0.015566
# 28017                                chest x-ray dataset        0.011214
# 8358                                                   a             NaN
# 2790                     public phenotype knowledge base         0.02187
# 5900                       pro spective follow-up cohort        0.464115
# 18868                                        nui galways        0.003272
# 14684                                             taiwan        0.008919
# 16455   multivariate intelligent monitoring in intensive        0.116214
# 22065  picture archiving and communication system (pacs)        0.005628
# 16204                                        intweresatl        0.000045
# 26092  korea university guro hospital (guro-gu, seoul...        0.292553
# 18677                   infinite biomedical technologies        0.000323
# 25009                       immunohistochemistry records         0.00294
# 4669                         aumc icu biosignal database        0.099602
# 17654  public and private clinical data from four ret...        0.002407
# 5526                                                   a             NaN
# 3819                                                ehrs        0.329612
# 25081                                                NaN             NaN
# 27153  research results that are not commercially ava...        0.000569
# 17907  clinical research center for medical equipment...        0.069016
# 14628  government hospital, kumbakonam, tamil nadu, i...        0.011156
# 11643                        victoria longitudinal study        0.557336
# 23948                                                NaN             NaN
# 8233                                      adni-1 dataset        0.568709
# 15359                                                3.1        0.026246
# 11215                           patients medical records        0.036978
# 19860  andreas bullings recognition-of-ofice-activiti...        0.574656
# 25877                                                NaN             NaN
# 16978  nimh-sponsored multimodal treatment study of a...        0.311989
# 15757  alzheimers disease neuroimaging initiative (ad...        0.456499
# 26417                     mimic-iii version 1.3 data set        0.613072
# 26399                        surfer. nmr.mgh.harvard.edu        0.000231
# 25262                                     epimed monitor        0.827218
# 3748                                   training data set        0.094352
# 16582                       clinical registry unit (cru)        0.067599
# 12808  university of new mexico human research review...        0.045683
# 17140                           national instrument (ni)        0.001725
# 20821                                                  a             NaN
# 28691                                    mesobank cohort        0.243911
# 8598                         single-center retrospective        0.004655
# 25707             medical association of berlin, germany        0.025944
# 15930       picture archiving and communications systems        0.869608
# 27348  tangdu hospital of the fourth military medical...        0.001302
#
#                                              method_db_2 method_db_score_2  \
# 8989                                   registry database          0.003598
# 2828                                                pdbp          0.071393
# 9550                                   mit-bih databases          0.000519
# 19443                                             rsfmri          0.004149
# 20254         image biomarker standardisation initiative          0.000656
# 8622                                                 NaN               NaN
# 28343                        social security death index           0.00212
# 4828                                    imagenet dataset          0.002699
# 28017  chest x-ray dataset provided by the 2019 siim-...           0.00965
# 8358                                                   a               NaN
# 2790                                        columbia cdw          0.010493
# 5900                                          excel 2016          0.000838
# 18868                               microsoft foundation          0.000236
# 14684           individual breast cancer surgery patient          0.000096
# 16455                                           mimic ii          0.013728
# 22065                                               pacs          0.003447
# 16204                severity measurement in et patients          0.000013
# 26092                             observer study dataset          0.018629
# 18677                                           training          0.000198
# 25009                                    medical reports          0.002699
# 4669                              aumc biosignal dataset           0.02055
# 17654                   cancer imaging phenomics toolkit          0.001057
# 5526                                                   a               NaN
# 3819                                                vfie          0.000767
# 25081                                                NaN               NaN
# 27153                            electronic chart review          0.000438
# 17907   healthy subjects or from patients with dysphagia          0.000608
# 14628  biological data requires a collection of techn...          0.000743
# 11643                                    bio-demographic          0.000082
# 23948                                                NaN               NaN
# 8233                                                 hte          0.008356
# 15359                           electronic health record          0.008245
# 11215                   peking university first hospital          0.005003
# 19860                                                eth          0.004192
# 25877                                                NaN               NaN
# 16978                                            mta 168            0.0058
# 15757                                fully pre-processed          0.000024
# 26417                   metavision database in mimic-iii          0.103344
# 26399                        wisconsin cart sort test-64           0.00016
# 25262                                                185          0.000019
# 3748                                         foresite pt          0.000894
# 16582                       vveerr- ssiioonn11.1.133.0.0           0.00028
# 12808                                     fmrib.ox.ac.uk          0.000411
# 17140                                               usrp          0.001125
# 20821                                                  a               NaN
# 28691  national clinicobiological database of the nat...          0.056385
# 8598                         achieva, philips healthcare          0.000078
# 25707                                    patient records          0.002493
# 15930                                            mricron          0.000044
# 27348                                               unet          0.000078
#
#                                               method_org method_org_score
# 8989                            three teaching hospitals         0.107208
# 2828   the parkinson's progression markers initiative...         0.172924
# 9550                                           main lead         0.000985
# 19443                  chaoyang hospital, beijing, china         0.310518
# 20254                                             french         0.170773
# 8622                                                 NaN              NaN
# 28343               beth israel deaconess medical center         0.591132
# 4828                                 university of miami         0.438837
# 28017                                             kaggle         0.006722
# 8358                                                   a              NaN
# 2790                                 columbia university         0.015407
# 5900                                             qingdao         0.944761
# 18868                                        nui galways         0.339933
# 14684                                    southern taiwan         0.905807
# 16455                                      the fingertip         0.003537
# 22065  chicago, illinois, united states), linear prob...          0.00062
# 16204                                        intweresatl         0.000277
# 26092                     korea university guro hospital         0.616967
# 18677                             johns hopkins medicine         0.000586
# 25009                                           2 oclock         0.002735
# 4669                  shaoxing peoples hospital of china         0.042832
# 17654                         university of pennsylvania         0.003321
# 5526                                                   a              NaN
# 3819    university of maribor faculty of health sciences         0.264767
# 25081                                                NaN              NaN
# 27153                  single large academic institution         0.379332
# 17907  clinical research center for medical equipment...         0.046445
# 14628                      kumbakonam, tamil nadu, india         0.064603
# 11643                              university of alberta         0.798233
# 23948                                                NaN              NaN
# 8233                                        loni.usc.edu         0.091067
# 15359                                              india         0.226673
# 11215                   peking university first hospital         0.354177
# 19860  andreas bullings recognition-of-ofice-activiti...         0.034922
# 25877                                                NaN              NaN
# 16978  nimh-sponsored multimodal treatment study of a...         0.136043
# 15757         alzheimers disease neuroimaging initiative         0.126909
# 26417               beth israel deaconess medical center         0.603647
# 26399                          1.5t ge signa mri scanner         0.000576
# 25262  irmandade santa casa de misericordia de porto ...         0.737029
# 3748                        southampton general hospital         0.315056
# 16582                               tertiary care center         0.010481
# 12808  university of new mexico hospital and the albu...         0.482632
# 17140                              university of glasgow         0.004607
# 20821                                                  a              NaN
# 28691                                    mesobank cohort         0.026142
# 8598                                       single-center         0.015674
# 25707             medical association of berlin, germany         0.439614
# 15930       picture archiving and communications systems         0.613961
# 27348  tangdu hospital of the fourth military medical...         0.027728

# %%
#all_database = all_database.fillna('')
#all_database["region_db"] = ""
#all_database["local_db"] = ""
#all_database["research_db"] = ""
#all_database["collection"] = ""
#all_database["other"] = ""

#all_database['method_db'] = all_database['method_db'].map(lambda x:x.lower() if type(x) == str else x)
#all_database['abstract_db'] = all_database['abstract_db'].map(lambda x:x.lower() if type(x) == str else x)

# %%
#from collections import Counter
## extract best guess
#text = ['electronic health', 'health record', 'electronic medical', 'medical record', 'clinical record', 
#        'information system', 'medical center', 'patient record', 'notes']

#for x in text:
#    all_database["extract"] = np.where(all_database['method_db'].str.contains(x), "1", all_database["extract"])
#    all_database["extract"] = np.where(all_database['abstract_db'].str.contains(x), "1", all_database["extract"])

##output
#print('text counts:')
#print(Counter(all_database["extract"]))
# Out:
# text counts:
# Counter({'': 27342, '1': 1361})

# %%
## research db best guess
#text = ['cohort', 'study', 'trial', 'research']
#
#for x in text:
#    all_database["research_db"] = np.where(all_database['method_db'].str.contains(x), "1", all_database["research_db"])
#    all_database["research_db"] = np.where(all_database['abstract_db'].str.contains(x), "1", all_database["research_db"])

##output
#print('text counts:')
#print(Counter(all_database["research_db"]))
# Out:
# text counts:
# Counter({'': 26082, '1': 2621})

# %%
all_database.to_csv('output/_annotation_database.csv')

# %%
## split

# %%
split_1 = all_database[0:5000]
split_2 = all_database[5000:10000]
split_3 = all_database[10000:15000]
split_4 = all_database[15000:20000]
split_5 = all_database[20000:25000]
split_6 = all_database[25000:28703]

# %%
split_1.to_csv('output/split_database_annotation/split_1.csv')
split_2.to_csv('output/split_database_annotation/split_2.csv')
split_3.to_csv('output/split_database_annotation/split_3.csv')
split_4.to_csv('output/split_database_annotation/split_4.csv')
split_5.to_csv('output/split_database_annotation/split_5.csv')
split_6.to_csv('output/split_database_annotation/split_6.csv')
