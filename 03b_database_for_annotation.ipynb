# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import re

# %% [markdown]
# # load data

# %%
all_abstracts = pd.read_csv('data/included_abstracts.csv', index_col = 0)

all_abstracts['article_date'] = pd.to_datetime(all_abstracts['article_date'])
decade_df = all_abstracts[(all_abstracts['article_date'] > '2012-01-01') & (all_abstracts['article_date'] <'2022-01-01')]
len(decade_df)
# Out:
# 28703

# %%
methods_df = pd.read_csv('output/methods_scored.csv', index_col = 0)
print(len(methods_df))
methods_df.info()
# Out:
# 9071
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9071 entries, 0 to 9070
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pmid                 9071 non-null   int64
#  1   title                9071 non-null   object
#  2   methods              9071 non-null   object
#  3   sample_answer        9071 non-null   object
#  4   sample_score         8648 non-null   float64
#  5   database_answer      9071 non-null   object
#  6   database_score       8648 non-null   float64
#  7   organisation_answer  9071 non-null   object
#  8   organisation_score   8648 non-null   float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 708.7+ KB

# %%
abstracts_df = pd.read_csv('output/abstracts_scored.csv', index_col = 0)
print(len(abstracts_df))
abstracts_df.info()
# Out:
# 28703
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28703 entries, 0 to 28702
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pmid                 28703 non-null  int64
#  1   title                28702 non-null  object
#  2   abstract             28703 non-null  object
#  3   disease_answer       28703 non-null  object
#  4   disease_score        28703 non-null  float64
#  5   sample_answer        28703 non-null  object
#  6   sample_score         28703 non-null  float64
#  7   modality_answer      28703 non-null  object
#  8   modality_score       28703 non-null  float64
#  9   database_answer      28703 non-null  object
#  10  database_score       28703 non-null  float64
#  11  organisation_answer  28703 non-null  object
#  12  organisation_score   28703 non-null  float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 3.1+ MB

# %% [markdown]
# # combined columns

# %%
abstract_databases = abstracts_df[['pmid', 'abstract', 'database_answer', 'database_score', 'organisation_answer', 'organisation_score']].copy()
abstract_databases.rename(columns={"database_answer": "abstract_db", "database_score": "abstract_db_score",
                                  "organisation_answer": "abstract_org", "organisation_score": "abstract_org_score"}, inplace=True)

method_databases = methods_df[['pmid', 'methods', 'database_answer', 'database_score', 'organisation_answer', 'organisation_score']].copy()
method_databases.rename(columns={"database_answer": "method_db", "database_score": "method_db_score",
                                  "organisation_answer": "method_org", "organisation_score": "method_org_score"}, inplace=True)

# %%
all_database = abstract_databases.merge(method_databases, on = 'pmid', how = 'left')
all_database = all_database[['pmid', 'abstract', 'methods', 'abstract_db', 'abstract_db_score',
                             'abstract_org', 'abstract_org_score', 'method_db' ,'method_db_score',
                            'method_org', 'method_org_score']].astype('object')

# %%
all_database.sample(50)
# Out:
#            pmid                                           abstract  \
# 18190  33914464  We developed, tested, and validated machine le...
# 8659   34482428  To develop and validate deep learning (DL) met...
# 10351  34364492  We report on the feasibility study exploring t...
# 8339   33927352  Glioblastoma is the most aggressive type of br...
# 7911   33850515  Accurate segmentation of the optic disc (OD) d...
# 5648   34457220  Most detection methods of coronavirus disease ...
# 12347  34926514  The photopic negative response of the full-fie...
# 5281   24043317  The objective was to develop non-invasive pred...
# 11370  31877845  Bruxism is a masticatory muscle activity chara...
# 7810   32046685  MR images (MRIs) accurate segmentation of brai...
# 14640  30776988  Numerous nonepileptic paroxysmal events, such ...
# 3205   31758002  Head injury models are important toolsÂ to stu...
# 7275   30679510  Current approaches to predicting a cardiovascu...
# 3762   34702188  Influenza is associated with excess morbidity ...
# 19508  32755226  <b>OBJECTIVE.</b> The purpose of this study wa...
# 27371  33201104  To develop a deep learning model to automatica...
# 4281   33447862  To investigate the application of machine lear...
# 4470   30226545  Tumor recurrence hinders treatment of ovarian ...
# 13573  22391013  In this paper, we present a novel approach for...
# 14746  32275915  The unparalleled performance of deep learning ...
# 6515   31915519  Breast cancer is the most common cancer among ...
# 3264   34378554  This study demonstrates a discrimination of en...
# 15374  33588121  How to fast and accurately assess the severity...
# 6047   32991011  The current prostate special antigen (PSA) tes...
# 5395   30836346  The objective of this study was to investigate...
# 612    31670697  Hemodynamic assessment of critically ill patie...
# 9460   30878526  This study aimed to identify the optimal radio...
# 4984   32554386  Early diabetes screening can effectively reduc...
# 26759  31911172  Acute Kidney Injury (AKI) is a common clinical...
# 11239  31632335  <b>Objective:</b> To explore whether or not fu...
# 5148   34152274  The Multidimensional Prognostic Index (MPI) is...
# 12494  33615120  Motor abnormalities have been shown to be a di...
# 28021  28107365  We make use of ideas from the theory of comple...
# 1566   30286740  To develop a deep neural network able to diffe...
# 17153  33224093  <b>Objective:</b> In this study, we investigat...
# 23152  34815000  This secondary data analysis study aimed to (1...
# 10597  29329721  Cystic fibrosis related diabetes (CFRD) is ass...
# 18932  23284677  Few studies of laparoscopic cholecystectomy (L...
# 28156  31063501  Electroencephalogram (EEG) is a common base si...
# 24427  32199650  To develop a radial basis function (RBF) neura...
# 5345   22903970  Diagnosis of primary ciliary dyskinesia (PCD) ...
# 19421  34757566  Left ventricular hypertrophy (LVH) is an indep...
# 25115  31093370  Although optical coherence tomography (OCT) is...
# 26870  33349492  We use variables from a recently derived acute...
# 8999   34056670  The rapid development of artificial intelligen...
# 23225  34600805  To develop and validate a radiomic model, with...
# 27332  31125389  Neurodegenerative diseases causing dementia ar...
# 12110  33339385  Brain magnetic resonance imaging (MRI) is usef...
# 26796  28932682  Our group recently employed genome-wide transc...
# 4952   34611840  The goal of this study was to develop and eval...
#
#                                                  methods  \
# 18190                                                NaN
# 8659                                                 NaN
# 10351                                                NaN
# 8339
# 7911                                                 NaN
# 5648                                                 NaN
# 12347                                                NaN
# 5281    A representative set of classification algori...
# 11370    2.1M.OatveerriaallsTarenadtmMenetthScohdesme...
# 7810             In this section, we describe details...
# 14640                                                NaN
# 3205                                                 NaN
# 7275    Study setting. We conducted the study using d...
# 3762     Design and patients            hTis was a se...
# 19508                                                NaN
# 27371                                                NaN
# 4281                                                 NaN
# 4470     Data resource and pretreatment Data from TCG...
# 13573                                                NaN
# 14746                                                NaN
# 6515             Figure 2 illustrates the stages of t...
# 3264    diagnostic methods mentioned above, has led t...
# 15374                                                NaN
# 6047                                                 NaN
# 5395                                                 NaN
# 612                                                  NaN
# 9460                                                 NaN
# 4984     Analysis            The data were analyzed w...
# 26759                                                NaN
# 11239                                                NaN
# 5148     Overview Details of the data collection meth...
# 12494   Participants Patients meeting DSM-5 criteria ...
# 28021            Data Methylation data, collected via...
# 1566     Data preparation The study was approved by t...
# 17153                                                NaN
# 23152                                                NaN
# 10597                                                NaN
# 18932    Ethics statement All patients who had underg...
# 28156                                                NaN
# 24427                                                NaN
# 5345                                                 NaN
# 19421    Study population            Data collection ...
# 25115                                                NaN
# 26870                                                NaN
# 8999    This retrospective study was approved by the ...
# 23225                                                NaN
# 27332                                                NaN
# 12110    2.1. Study Participants We used a prospectiv...
# 26796                                                NaN
# 4952                                                 NaN
#
#                                              abstract_db abstract_db_score  \
# 18190                                           BREAST-Q          0.171535
# 8659                    training and validation datasets          0.044365
# 10351  people aged 19-88 with different tumor grades ...          0.025304
# 8339                                 Cancer Genome Atlas          0.442231
# 7911       our collected dataset and six public datasets          0.055616
# 5648                            coronavirus disease 2019           0.21782
# 12347  109 optic neuropathy and 108 controls) of 155 ...          0.030059
# 5281   Monroe Carell Jr. Children's Hospital at Vande...           0.20516
# 11370  Bruxism is a masticatory muscle activity chara...          0.000726
# 7810   Ischemic Stroke Lesion Segmentation (ISLES) 20...          0.124099
# 14640  electroencephalograms (EEGs), epileptiform dis...          0.009855
# 3205                                   American football          0.300234
# 7275                            electronic health record          0.508362
# 3762      Rapid Empiric Treatment with Oseltamivir Study          0.325217
# 19508                                          radiomics          0.165061
# 27371                                          LC videos          0.073362
# 4281                                         Pyradiomics          0.385553
# 4470                                       TCGA database          0.594934
# 13573     Open Access Series of Imaging Studies data set          0.603297
# 14746                                               sMRI          0.257278
# 6515                                    segmented breast          0.007867
# 3264                                              plasma          0.006796
# 15374                                           COVID-19          0.028245
# 6047                        Cancer Genome Atlas database          0.234814
# 5395   Surface electromyogram (sEMG) signals of six h...          0.052927
# 612                      Simple Intensive Care Studies-I          0.582682
# 9460                                         PyRadiomics          0.326758
# 4984    National Health and Nutrition Examination Survey          0.790634
# 26759                           electronic health record          0.217352
# 11239  Thirty-eight drug-naive patients with PI, and ...          0.008503
# 5148                                 Australian patients          0.135531
# 12494                                        smartphones           0.10631
# 28021             patients with various kinds of cancers          0.204335
# 1566                                        visual filed          0.292479
# 17153                            Philips Medical Systems          0.121281
# 23152  Collaborative Aging Research Using Technology ...          0.768131
# 10597                 continuous glucose monitoring data          0.376318
# 18932  laparoscopic cholecystectomy (LC) outcome have...          0.115804
# 28156                                Physionet Sleep-EDF          0.750327
# 24427     Modification of Diet in Renal Disease equation          0.042006
# 5345                                                 151          0.016602
# 19421                           cardiac amyloidosis (CA)          0.120361
# 25115                                        normal eyes          0.020163
# 26870                          electronic health records          0.181451
# 8999                                lateral cephalograms          0.053411
# 23225                                       111 patients          0.062327
# 27332                           specialist memory clinic          0.231598
# 12110                                                AIS          0.043222
# 26796  National Center for Biotechnology Information ...          0.610158
# 4952                                          EskiÅŸehir          0.431675
#
#                                             abstract_org abstract_org_score  \
# 18190                                      North America           0.383384
# 8659                    training and validation datasets           0.001829
# 10351  people aged 19-88 with different tumor grades ...            0.00592
# 8339                                 Cancer Genome Atlas           0.464841
# 7911       our collected dataset and six public datasets           0.007581
# 5648                            coronavirus disease 2019           0.012178
# 12347                                             clinic           0.029246
# 5281   Monroe Carell Jr. Children's Hospital at Vande...           0.414958
# 11370                                            bruxism           0.001186
# 7810                                               BRATS           0.018731
# 14640                       EEG data without overlapping           0.002452
# 3205                                   American football           0.161492
# 7275                          American Heart Association           0.094883
# 3762      Rapid Empiric Treatment with Oseltamivir Study           0.221266
# 19508                                          radiomics            0.01389
# 27371                                          LC videos           0.017563
# 4281                                         Pyradiomics           0.242354
# 4470                                       TCGA database           0.537968
# 13573     Open Access Series of Imaging Studies data set           0.464962
# 14746                                               sMRI           0.089071
# 6515                                Mammary thermography           0.004609
# 3264                                              plasma           0.004676
# 15374                                           chest CT           0.003429
# 6047                        Cancer Genome Atlas database           0.133639
# 5395   spinal cord injury (SCI).Surface electromyogra...           0.005775
# 612                      Simple Intensive Care Studies-I           0.461258
# 9460                                         PyRadiomics           0.100494
# 4984    National Health and Nutrition Examination Survey           0.741258
# 26759                                      critical care           0.193028
# 11239  Thirty-eight drug-naive patients with PI, and ...           0.003128
# 5148                           South Australian hospital           0.181609
# 12494                                        smartphones           0.206993
# 28021             patients with various kinds of cancers           0.205439
# 1566                                  ophthalmic centers           0.232609
# 17153                            Philips Medical Systems           0.080776
# 23152                 Oregon Health & Science University           0.593247
# 10597                 continuous glucose monitoring data           0.086479
# 18932             Gastrointestinal Quality of Life Index           0.015271
# 28156                                Physionet Sleep-EDF           0.769918
# 24427     Modification of Diet in Renal Disease equation           0.001971
# 5345   nasal epithelial cell culture can speed PCD di...           0.006593
# 19421                                               view           0.021291
# 25115                                  retina specialist           0.027062
# 26870                                  adult health plan           0.273199
# 8999               lateral cephalograms from 35 patients            0.00845
# 23225                                          radiomics           0.018027
# 27332                                     memory clinics           0.281271
# 12110           radiology free-text reports of brain MRI           0.025418
# 26796  National Center for Biotechnology Information ...           0.641236
# 4952                                          EskiÅŸehir           0.136558
#
#                                                method_db method_db_score  \
# 18190                                                NaN             NaN
# 8659                                                 NaN             NaN
# 10351                                                NaN             NaN
# 8339                                                   a             NaN
# 7911                                                 NaN             NaN
# 5648                                                 NaN             NaN
# 12347                                                NaN             NaN
# 5281                                           dataset 2        0.000539
# 11370                                   occlusion stress        0.001502
# 7810                                  3D volumetric MRIs        0.004826
# 14640                                                NaN             NaN
# 3205                                                 NaN             NaN
# 7275                                Synthetic Derivative        0.764836
# 3762   Rapid Empiric Treatment with Oseltamivir Study...        0.012507
# 19508                                                NaN             NaN
# 27371                                                NaN             NaN
# 4281                                                 NaN             NaN
# 4470                                        GEO database         0.19375
# 13573                                                NaN             NaN
# 14746                                                NaN             NaN
# 6515   e dataset includes 63 thermographic images (35...        0.000232
# 3264   mid-infrared (MIR) spectroscopy for assisting ...        0.000021
# 15374                                                NaN             NaN
# 6047                                                 NaN             NaN
# 5395                                                 NaN             NaN
# 612                                                  NaN             NaN
# 9460                                                 NaN             NaN
# 4984                                     NHANES database        0.724534
# 26759                                                NaN             NaN
# 11239                                                NaN             NaN
# 5148          Flinders Medical Centre Acute Medical Unit         0.35767
# 12494                          Mount Sinai Health System        0.017097
# 28021                 Cancer Genome Atlas (TCGA) project        0.554174
# 1566                         Zhongshan Ophthalmic Center        0.105723
# 17153                                                NaN             NaN
# 23152                                                NaN             NaN
# 10597                                                NaN             NaN
# 18932                      Medical University   Hospital        0.123747
# 28156                                                NaN             NaN
# 24427                                                NaN             NaN
# 5345                                                 NaN             NaN
# 19421                          echocardiography database        0.155543
# 25115                                                NaN             NaN
# 26870                                                NaN             NaN
# 8999   Chonnam National University Dental Hospital, G...        0.039286
# 23225                                                NaN             NaN
# 27332                                                NaN             NaN
# 12110                                    stroke database        0.304359
# 26796                                                NaN             NaN
# 4952                                                 NaN             NaN
#
#                                               method_org method_org_score
# 18190                                                NaN              NaN
# 8659                                                 NaN              NaN
# 10351                                                NaN              NaN
# 8339                                                   a              NaN
# 7911                                                 NaN              NaN
# 5648                                                 NaN              NaN
# 12347                                                NaN              NaN
# 5281                        neonatal intensive care unit         0.001809
# 11370                    Ivoclar Vivadent, Liechtenstein         0.006605
# 7810                                               ISLES          0.00014
# 14640                                                NaN              NaN
# 3205                                                 NaN              NaN
# 7275                                                VUMC         0.775324
# 3762                                            Kentucky         0.249599
# 19508                                                NaN              NaN
# 27371                                                NaN              NaN
# 4281                                                 NaN              NaN
# 4470                                        GEO database         0.047142
# 13573                                                NaN              NaN
# 14746                                                NaN              NaN
# 6515                                 breast localization         0.001489
# 3264   mid-infrared (MIR) spectroscopy for assisting ...         0.000018
# 15374                                                NaN              NaN
# 6047                                                 NaN              NaN
# 5395                                                 NaN              NaN
# 612                                                  NaN              NaN
# 9460                                                 NaN              NaN
# 4984                                     NHANES database         0.106471
# 26759                                                NaN              NaN
# 11239                                                NaN              NaN
# 5148                             Flinders Medical Centre         0.515721
# 12494                          Mount Sinai Health System         0.502021
# 28021                 Cancer Genome Atlas (TCGA) project         0.171472
# 1566                         Zhongshan Ophthalmic Center         0.813358
# 17153                                                NaN              NaN
# 23152                                                NaN              NaN
# 10597                                                NaN              NaN
# 18932                                    southern Taiwan         0.859041
# 28156                                                NaN              NaN
# 24427                                                NaN              NaN
# 5345                                                 NaN              NaN
# 19421  First Alfiiated Hospital, School of Medicine, ...         0.466579
# 25115                                                NaN              NaN
# 26870                                                NaN              NaN
# 8999   Chonnam National University Dental Hospital, G...         0.535236
# 23225                                                NaN              NaN
# 27332                                                NaN              NaN
# 12110                    Chuncheon Sacred Heart Hospital          0.03629
# 26796                                                NaN              NaN
# 4952                                                 NaN              NaN

# %%
#all_database = all_database.fillna('')
#all_database["region_db"] = ""
#all_database["local_db"] = ""
#all_database["research_db"] = ""
#all_database["collection"] = ""
#all_database["other"] = ""

#all_database['method_db'] = all_database['method_db'].map(lambda x:x.lower() if type(x) == str else x)
#all_database['abstract_db'] = all_database['abstract_db'].map(lambda x:x.lower() if type(x) == str else x)

# %%
#from collections import Counter
## extract best guess
#text = ['electronic health', 'health record', 'electronic medical', 'medical record', 'clinical record', 
#        'information system', 'medical center', 'patient record', 'notes']

#for x in text:
#    all_database["extract"] = np.where(all_database['method_db'].str.contains(x), "1", all_database["extract"])
#    all_database["extract"] = np.where(all_database['abstract_db'].str.contains(x), "1", all_database["extract"])

##output
#print('text counts:')
#print(Counter(all_database["extract"]))
# Out:
# text counts:
# Counter({'': 27342, '1': 1361})

# %%
## research db best guess
#text = ['cohort', 'study', 'trial', 'research']
#
#for x in text:
#    all_database["research_db"] = np.where(all_database['method_db'].str.contains(x), "1", all_database["research_db"])
#    all_database["research_db"] = np.where(all_database['abstract_db'].str.contains(x), "1", all_database["research_db"])

##output
#print('text counts:')
#print(Counter(all_database["research_db"]))
# Out:
# text counts:
# Counter({'': 26082, '1': 2621})

# %%
all_database.to_csv('output/_annotation_database.csv')
