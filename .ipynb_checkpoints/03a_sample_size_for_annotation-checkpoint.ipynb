# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import re

# %% [markdown]
# # load data

# %%
all_abstracts = pd.read_csv('data/included_abstracts.csv', index_col = 0)

all_abstracts['article_date'] = pd.to_datetime(all_abstracts['article_date'])
decade_df = all_abstracts[(all_abstracts['article_date'] > '2012-01-01') & (all_abstracts['article_date'] <'2022-01-01')]
len(decade_df)
# Out:
# 28703

# %%
methods_df = pd.read_csv('output/methods_scored.csv', index_col = 0)
print(len(methods_df))
methods_df.info()
# Out:
# 9071
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9071 entries, 0 to 9070
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pmid                 9071 non-null   int64
#  1   title                9071 non-null   object
#  2   methods              9071 non-null   object
#  3   sample_answer        9071 non-null   object
#  4   sample_score         8648 non-null   float64
#  5   database_answer      9071 non-null   object
#  6   database_score       8648 non-null   float64
#  7   organisation_answer  9071 non-null   object
#  8   organisation_score   8648 non-null   float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 708.7+ KB

# %%
abstracts_df = pd.read_csv('output/abstracts_scored.csv', index_col = 0)
print(len(abstracts_df))
abstracts_df.info()
# Out:
# 28703
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28703 entries, 0 to 28702
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pmid                 28703 non-null  int64
#  1   title                28702 non-null  object
#  2   abstract             28703 non-null  object
#  3   disease_answer       28703 non-null  object
#  4   disease_score        28703 non-null  float64
#  5   sample_answer        28703 non-null  object
#  6   sample_score         28703 non-null  float64
#  7   modality_answer      28703 non-null  object
#  8   modality_score       28703 non-null  float64
#  9   database_answer      28703 non-null  object
#  10  database_score       28703 non-null  float64
#  11  organisation_answer  28703 non-null  object
#  12  organisation_score   28703 non-null  float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 3.1+ MB

# %% [markdown]
# # abstract sample sizes

# %%
# all letters to lower case
abstracts_df['sample_answer'] = abstracts_df['sample_answer'].map(lambda x:x.lower() if type(x) == str else x) #reduce all to lowercase

# %%
# convert text numbers to numeric

from text_to_num import alpha2digit

templist = []

for x in abstracts_df['sample_answer']:
    try:
        templist.append(alpha2digit(x, "en"))
    except Exception as e:
        print(e)
        templist.append('skip')

abstracts_df['sample_answer'] = templist

# %%
# remove commas (no spaces)
abstracts_df['sample_answer']=abstracts_df['sample_answer'].str.replace(',','')

# %%
# remove entries with no numeric characters
def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

templist2 = []

for x in abstracts_df['sample_answer']:
    if has_numbers(x) == True:
        templist2.append(x)
    else:
        templist2.append(np.nan)

abstracts_df['sample_answer'] = templist2

# %%
#abstracts_df['sample_answer'].sample(15)

# %% [markdown]
# # methods sample sizes

# %%
# all letters to lower case
methods_df['sample_answer'] = methods_df['sample_answer'].map(lambda x:x.lower() if type(x) == str else x) #reduce all to lowercase

# %%
# convert text numbers to numeric

from text_to_num import alpha2digit

templist = []

for x in methods_df['sample_answer']:
    try:
        templist.append(alpha2digit(x, "en"))
    except Exception as e:
        print(e)
        templist.append('skip')

methods_df['sample_answer'] = templist

# %%
# remove commas (no spaces)
methods_df['sample_answer']=methods_df['sample_answer'].str.replace(',','')

# %%
templist2 = []

for x in methods_df['sample_answer']:
    if has_numbers(x) == True:
        templist2.append(x)
    else:
        templist2.append(np.nan)

methods_df['sample_answer'] = templist2

# %%
#methods_df.sample(15)

# %% [markdown]
# # sample size sheet and combined truth column for annotation

# %%
abstract_sizes = abstracts_df[['abstract', 'pmid', 'sample_answer', 'sample_score']].copy()
abstract_sizes.rename(columns={"sample_answer": "abstract_size", "sample_score": "abstract_score"}, inplace=True)

method_sizes = methods_df[['methods', 'pmid', 'sample_answer', 'sample_score']].copy()
method_sizes.rename(columns={"sample_answer": "method_size", "sample_score": "method_score"}, inplace=True)

# %%
all_sizes = abstract_sizes.merge(method_sizes, on = 'pmid', how = 'left')
all_sizes = all_sizes[['pmid', 'abstract', 'methods', 'abstract_size', 'abstract_score', 'method_size', 'method_score']].astype('object')

# %%
## rules for generating truth column
# (1) keep only absolute numerics from abstract / method sizes
# (2) keep all method derived sizes
# (3) where method probability is below threshold, AND if the abstract size is larger, drop the method size
# (4) where method = NaN, replace with abstract derived size

# %%
templist = []

for x in all_sizes['abstract_size']:
    try:
        if x.isdigit() == True:
            templist.append(x)
        else:
            templist.append(np.nan)
    except:
        templist.append(np.nan)
        
all_sizes['abstract_truth'] = templist

#check if only contains numbers in method

templist = []

for x in all_sizes['method_size']:
    try:
        if x.isdigit() == True:
            templist.append(x)
        else:
            templist.append(np.nan)
    except:
        templist.append(np.nan)
        
all_sizes['method_truth'] = templist

all_sizes[['abstract_truth', 'method_truth']] = all_sizes[['abstract_truth', 'method_truth']].apply(pd.to_numeric)

# %%
templist = []

for i, row in all_sizes.iterrows():
    if row['method_score'] < 0.0005 and row['abstract_truth'] > row['method_truth']:
        templist.append(np.nan)
    else:
        templist.append(row['method_truth'])

all_sizes['method_truth'] = templist

# %%
all_sizes = all_sizes.assign(size_truth = all_sizes['method_truth'].fillna(all_sizes['abstract_truth']))

# %%
all_sizes.sample(50)
# Out:
#            pmid                                           abstract  \
# 13203  33937859  To automate skeletal muscle segmentation in a ...
# 18660  23313839  Little is known about the ability of natural l...
# 28508  33392576  Accurate triage in the emergency department (E...
# 4232   31957147  This study investigated whether infrared spect...
# 12492  33897397  Over the last few decades, electroencephalogra...
# 25132  34389965  In conjunction with recent advancements in mac...
# 9731   34999410  Low vision rehabilitation improves quality-of-...
# 23114  26599106  Genetic profiling represents the future of neu...
# 8401   33981950  Benign breast disease (BBD) is a strong breast...
# 15459  31628932  Concussion, also referred to as mild traumatic...
# 28300  31447329  The field of psychiatry has long sought biomar...
# 20261  29807250  The electroencephalogram (EEG) is the most pro...
# 2843   32600154  To determine whether machine learning (ML) can...
# 3583   33323187  Spectral-domain optical coherence tomography (...
# 6044   33931925  Traditional histopathology performed by pathol...
# 3997   34253767  Surgeons must visually distinguish soft-tissue...
# 15365  28416144  Parkinson's disease (PD) is currently incurabl...
# 16140  31275176  <b>Background and Purpose.</b> The use of mach...
# 11230  35004599  <b>Background:</b> The etiology of fever of un...
# 175    34135637  Cardiovascular disease (CVD) is the leading ca...
# 16801  32722111  Diagnosis of pathologies using histopathologic...
# 14392  23317809  Early detection of Heart Failure (HF) could mi...
# 16614  34573884  Short tau inversion recovery (STIR) sequences ...
# 22943  34889949  The proposed MOLEM (Management of Lesion to Ex...
# 7000   32906052  Suicide is a serious social and public health ...
# 16993  31671805  Hepatocellular carcinoma (HCC) pathogenesis in...
# 18738  29994380  Due to the importance of nuclear structure in ...
# 8724   32306186  Dysphagia has a large impact on the society be...
# 16713  33445601  Motion intention detection is fundamental in t...
# 1732   26092859  In prognosis and survival studies, an importan...
# 15739  33916907  The loss of mobility function and sensory info...
# 11575  34450984  One of the most powerful techniques to diagnos...
# 2568   29782036  This study aimed to deduce evidence-based clin...
# 7659   34420233  Deep-learning algorithms (DLAs) have been used...
# 26398  34376505  Silent cerebrovascular disease (SCD), comprisi...
# 101    33568946  To investigate the predictive performance of d...
# 28142  31124079  Major depressive disorder (MDD) is characteriz...
# 20627  31733590  A targeted and timely offered treatment can be...
# 390    33289354  To evaluate the diagnostic performance of a de...
# 2577   33837284  Quantitative single-photon emission computed t...
# 27201  31698241  To determine whether deep learning-based algor...
# 22321  29540608  Stroke imaging is pivotal for diagnosis and st...
# 13949  32222809  Unlike the normal organ segmentation task, aut...
# 19633  31737428  To achieve automatic diabetic retinopathy (DR)...
# 770    32130159  Acute and chronic low back pain (LBP) are diff...
# 23291  33561673  The COVID-19 pandemic is a significant public ...
# 11653  24961214  The measurement of human respiratory signals i...
# 24110  34855599  Although deep learning techniques have made gr...
# 14422  33933712  Malignant ventricular arrhythmias (MAs) occur ...
# 15463  32980505  Survival varies in patients with glioblastoma ...
#
#                                                  methods  \
# 13203                                                NaN
# 18660                                                NaN
# 28508                                                NaN
# 4232                                                 NaN
# 12492            In the literature, not all previous ...
# 25132    Study Design and Patient Population         ...
# 9731                                                 NaN
# 23114    We recruited primary GBM patients undergoing...
# 8401     Study Population and Design            We co...
# 15459                                                NaN
# 28300                                                NaN
# 20261                                                NaN
# 2843                                                 NaN
# 3583                                                 NaN
# 6044                                                 NaN
# 3997    hTis study utilizes retrospectively acquired,...
# 15365                                                NaN
# 16140            We performed two ML analyses: the fi...
# 11230                                                NaN
# 175      Study Population            Multistage (pref...
# 16801    4.1. Datasets We used the following two publ...
# 14392                                                NaN
# 16614                                                NaN
# 22943
# 7000                                                 NaN
# 16993    2.1. Patients Between February 2012 and Marc...
# 18738                                                NaN
# 8724                                                 NaN
# 16713                                                NaN
# 1732     2.1 Overview of NCC-AUC We propose a novel m...
# 15739   2.1. NinaPro Database In this study, the Nina...
# 11575                                                NaN
# 2568                                                 NaN
# 7659                                                 NaN
# 26398                                                NaN
# 101      Patients This study was approved by the Ethi...
# 28142                                                NaN
# 20627                                                NaN
# 390                                                  NaN
# 2577    Dataset. hTree datasets were used in the curr...
# 27201                                                NaN
# 22321                                                NaN
# 13949                                                NaN
# 19633                                                NaN
# 770      Overview The conceptual steps of this study ...
# 23291                                                NaN
# 11653   respiration rate. They considered two types o...
# 24110                                                NaN
# 14422                                                NaN
# 15463                                                NaN
#
#                      abstract_size abstract_score method_size method_score  \
# 13203                          370       0.603823         NaN          NaN
# 18660                        10798       0.640644         NaN          NaN
# 28508                       265572       0.659106         NaN          NaN
# 4232                             9       0.659201         NaN          NaN
# 12492                            3       0.478481         NaN     0.000085
# 25132                         3178       0.411547           2     0.421381
# 9731                          5547       0.909553         NaN          NaN
# 23114                           82       0.223857         NaN     0.003104
# 8401                       15â 395       0.712636      15 395     0.474894
# 15459                           17         0.6465         NaN          NaN
# 28300                          531       0.450366         NaN          NaN
# 20261                          185       0.635237         NaN          NaN
# 2843                          3753       0.745834         NaN          NaN
# 3583                          4877       0.848492         NaN          NaN
# 6044                           643       0.872334         NaN          NaN
# 3997                           NaN       0.014456         130     0.104287
# 15365                           65       0.513548         NaN          NaN
# 16140                          175       0.619149          40     0.037833
# 11230                          527       0.739644         NaN          NaN
# 175                           1508       0.754539        1771     0.052244
# 16801                            2       0.204724          82     0.090999
# 14392                          NaN       0.013604         NaN          NaN
# 16614                          514       0.444955         NaN          NaN
# 22943                          217       0.351164         NaN          NaN
# 7000                        372813       0.821007         NaN          NaN
# 16993                           10       0.049315          53     0.387882
# 18738                          260        0.77387         NaN          NaN
# 8724                            19       0.822365         NaN          NaN
# 16713                           10       0.216287         NaN          NaN
# 1732   5 subtypes of breast cancer       0.143821        1981      0.11526
# 15739                          NaN       0.026797          10     0.105264
# 11575                          NaN       0.025252         NaN          NaN
# 2568                            29       0.715659         NaN          NaN
# 7659                            35       0.328667         NaN          NaN
# 26398                       262875       0.192891         NaN          NaN
# 101                            137       0.758433          50     0.003577
# 28142                           60       0.854687         NaN          NaN
# 20627                         1067        0.92553         NaN          NaN
# 390                           2601       0.405156         NaN          NaN
# 2577                           333       0.024057         333      0.14726
# 27201                          131       0.837119         NaN          NaN
# 22321                          195       0.790319         NaN          NaN
# 13949                            3       0.050442         NaN          NaN
# 19633                         5278       0.596598         NaN          NaN
# 770                          17409       0.818075       15715     0.173026
# 23291                         1560       0.799184         NaN          NaN
# 11653                           11       0.160275           2     0.000344
# 24110                          NaN       0.210208         NaN          NaN
# 14422                            3       0.073922         NaN          NaN
# 15463                          181       0.667142         NaN          NaN
#
#        abstract_truth  method_truth  size_truth
# 13203           370.0           NaN       370.0
# 18660         10798.0           NaN     10798.0
# 28508        265572.0           NaN    265572.0
# 4232              9.0           NaN         9.0
# 12492             3.0           NaN         3.0
# 25132          3178.0           2.0         2.0
# 9731           5547.0           NaN      5547.0
# 23114            82.0           NaN        82.0
# 8401              NaN           NaN         NaN
# 15459            17.0           NaN        17.0
# 28300           531.0           NaN       531.0
# 20261           185.0           NaN       185.0
# 2843           3753.0           NaN      3753.0
# 3583           4877.0           NaN      4877.0
# 6044            643.0           NaN       643.0
# 3997              NaN         130.0       130.0
# 15365            65.0           NaN        65.0
# 16140           175.0          40.0        40.0
# 11230           527.0           NaN       527.0
# 175            1508.0        1771.0      1771.0
# 16801             2.0          82.0        82.0
# 14392             NaN           NaN         NaN
# 16614           514.0           NaN       514.0
# 22943           217.0           NaN       217.0
# 7000         372813.0           NaN    372813.0
# 16993            10.0          53.0        53.0
# 18738           260.0           NaN       260.0
# 8724             19.0           NaN        19.0
# 16713            10.0           NaN        10.0
# 1732              NaN        1981.0      1981.0
# 15739             NaN          10.0        10.0
# 11575             NaN           NaN         NaN
# 2568             29.0           NaN        29.0
# 7659             35.0           NaN        35.0
# 26398        262875.0           NaN    262875.0
# 101             137.0          50.0        50.0
# 28142            60.0           NaN        60.0
# 20627          1067.0           NaN      1067.0
# 390            2601.0           NaN      2601.0
# 2577            333.0         333.0       333.0
# 27201           131.0           NaN       131.0
# 22321           195.0           NaN       195.0
# 13949             3.0           NaN         3.0
# 19633          5278.0           NaN      5278.0
# 770           17409.0       15715.0     15715.0
# 23291          1560.0           NaN      1560.0
# 11653            11.0           NaN        11.0
# 24110             NaN           NaN         NaN
# 14422             3.0           NaN         3.0
# 15463           181.0           NaN       181.0

# %%
all_sizes.to_csv('output/_annotation_sizes.csv')
